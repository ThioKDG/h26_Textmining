# %%
from mylib.sentiment_analyzer import SentimentAnalyzer

sa = SentimentAnalyzer('./model/sa_movie_model.keras', './model/sa_movie_encoder.pkl')
reviews = [
    '이 영화 개꿀잼 ㅋㅋㅋ',
    '하품만 나온다',
    '이 영화 핵노잼 ㅠㅠ',
    '이딴게 영화냐 ㅉㅉ',
    '와 개쩐다',
    '감독 뭐하는 놈이냐',
    '정말 세계관 최강자들의 영화다'
]

for review in reviews:
    user_output, prob = sa.analyze_sentiment(review)
    print(f'{review} --> {user_output}({prob*100:.2f}%)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 15
#       4 reviews = [
#       5     '이 영화 개꿀잼 ㅋㅋㅋ',
#       6     '하품만 나온다',
#    (...)
#      11     '정말 세계관 최강자들의 영화다'
#      12 ]
#      14 for review in reviews:
# ---> 15     user_output, prob = sa.analyze_sentiment(review)
#      16     print(f'{review} --> {user_output}({prob*100:.2f}%)')
#
# TypeError: analyze_sentiment() takes 1 positional argument but 2 were given
