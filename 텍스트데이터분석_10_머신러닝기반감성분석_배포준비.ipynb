# %%
# 한국어 토크나이저 정의
from konlpy.tag import Okt
def korean_tokenizer(text):
    my_tags = ['Noun', 'Adjective', 'Verb']
    my_stopwords = []
    tokenizer = Okt().pos
    return [word for word, tag in tokenizer(text) if tag in my_tags and word not in my_stopwords]

# %%
# 모델 로딩
import joblib
vectorizer_file = './model/se_movie_vectorizer.pkl'
model_file = './model/se_movie_vecorizer.pkl'

vectorizer = joblib.load(vectorizer_file)
sa_model = joblib.load(model_file)

# %%
# 함수 코드
def analyze_sentimant(review) :
    # 전처리 및 특징 벡터 추출
    review_fv = vectorizer.transform([review])

    result = sa_model.predict(review_fv)

    show = '긍정' if result[0] >= 0.5 else '부정'
    return show

# %%
reviews = [
    '영화가 너무 재미있다.',
    '이게 영화냐? 나도 만들겠다',
    '개꿀잼',
    '핵노잼'
]

for review in reviews:
    print(f'{review} -> {analyze_sentimant(review)}')
# Out:
#   (np.int32(0), np.int32(626))	0.28850957353384704
#   (np.int32(0), np.int32(761))	0.9574770106792736
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       1 reviews = [
#       2     '영화가 너무 재미있다.',
#       3     '이게 영화냐? 나도 만들겠다',
#       4     '개꿀잼',
#       5     '핵노잼'
#       6 ]
#       8 for review in reviews:
# ----> 9     print(f'{review} -> {analyze_sentimant(review)}')
#
# Cell In[3], line 7, in analyze_sentimant(review)
#       4 review_fv = vectorizer.transform([review])
#       5 print(review_fv)
# ----> 7 result = rf.predict(review_fv)
#       8 print(result)
#      10 show = '긍정' if result[0] >= 0.5 else '부정'
#
# NameError: name 'rf' is not defined
