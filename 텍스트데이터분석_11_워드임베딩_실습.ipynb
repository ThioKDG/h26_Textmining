# %% [markdown]
# # 영화 리뷰 워드 임베딩 (Word2Vec, FastText)
# - gensim 라이브러리 사용 : pip install gensim
#     - Word2Vec : models.Word2Vec
#     - FastText : models.FastText

# %% [markdown]
# ## 1. 데이터 준비
# * 토큰화가 잘 되어 있는 filtered 데이터 사용

# %%
import pandas as pd
data_filename = './data/Korean_movie_reviews_2016_filtered.csv'
data_df = pd.read_csv(data_filename)
data_df.head()
# Out:
#                                               review  rate
# 0                           아니 딴 그렇 비 비탄 총 대체 왜 들 온겨     7
# 1      진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임     1
# 2  역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 ...    10
# 3                                     온종일 불편한 피 범벅 일     6
# 4    답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐     1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788189 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    788189 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 12.0+ MB

# %%
# 결측치 제거 (rate에 결측치)
# 결측치를 제거하지 않으면 review 데이터 추출 시 float으로 타입 변환됨
data_df.dropna(inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785448 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    785448 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 18.0+ MB

# %%
# review만 모아서 review별 토큰 리스트로 변환 
review_list = list(map(str, data_df.review))
review_list[:5]
# Out:
# ['아니 딴 그렇 비 비탄 총 대체 왜 들 온겨',
#  '진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임',
#  '역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 실사 했 사람 거르려 그냥 봤 정말 흠잡 없는 최고 좀비 영화 잔인 거 싫어하지 참고 볼 만하 로미 인물 왜 그런 모르',
#  '온종일 불편한 피 범벅 일',
#  '답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐']

# %%
type(review_list[0])
# Out:
# str

# %%
# 결측치 처리 시 AttributeError 예외 발생
token_list = [review.split() for review in review_list]
token_list[:2]
# Out:
# [['아니', '딴', '그렇', '비', '비탄', '총', '대체', '왜', '들', '온겨'],
#  ['진심',
#   '쓰레기',
#   '영화',
#   '만들',
#   '무서',
#   '알',
#   '쫄아',
#   '틀었',
#   '이건',
#   '뭐',
#   '웃',
#   '거리',
#   '없는',
#   '쓰레기',
#   '영화',
#   '임']]

# %% [markdown]
# ## 1. Word2Vec 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/word2vec.html

# %% [markdown]
# ### Skipgram, negative=10 인 경우

# %%
# Word2Vec 모델 생성 및 학습 : window=3, min_count=3
from gensim.models import Word2Vec
model_sg_n10 = Word2Vec(token_list, window=3, min_count=3, sg=1, negative=10, vector_size=100)

# %%
# 단어의 임베딩 벡터 확인
model_sg_n10.wv['이정재']
# Out:
# array([-1.3772587e-01, -2.7103198e-01, -6.8208165e-02, -2.1377961e-01,
#         1.2904901e-02, -9.1823116e-02,  2.0214102e-01,  9.5567964e-03,
#         8.9892769e-01, -1.4295870e-01, -6.7659700e-04, -3.3973676e-01,
#        -1.7089424e-01,  3.0166933e-01, -2.3628390e-01, -1.3030742e-01,
#         8.6916871e-02,  3.3619085e-01,  5.6631610e-02, -1.6025297e-01,
#         1.4061733e-01,  3.2836970e-02,  3.1807357e-01,  8.9922585e-02,
#        -2.5050843e-01, -6.0104394e-01,  1.0936676e-03, -9.0452798e-02,
#        -1.7143919e-01, -5.0991076e-01,  3.3124155e-01,  2.1201882e-01,
#        -1.0577466e-01, -6.9955714e-02, -1.8815935e-01, -3.4303579e-01,
#        -3.3471525e-01,  9.9132560e-02, -3.2343218e-01, -1.7452161e-01,
#        -3.7881252e-01,  3.0983904e-01, -2.7111390e-01, -2.4659096e-01,
#        -1.5757583e-01,  9.4771497e-03, -3.9094817e-02, -3.1622329e-01,
#        -3.0809066e-01, -1.4870256e-01,  3.4122953e-01, -5.8551949e-01,
#        -4.2051777e-02, -1.5867262e-01, -1.9797469e-02,  9.0775989e-02,
#         1.7289832e-01,  3.2766532e-02,  1.8110465e-01, -8.0877796e-02,
#        -4.9322087e-01, -4.3310314e-02,  6.4789146e-01, -2.6473254e-01,
#        -7.8828210e-01, -3.4760061e-01, -2.3793910e-02, -4.2578378e-01,
#        -6.3325525e-03, -2.9729933e-02,  6.9158059e-01, -6.3334900e-04,
#        -9.2213750e-02,  6.2735504e-01,  2.0693855e-01, -9.7515427e-02,
#         2.5234792e-01, -3.7154987e-01, -6.1307734e-01, -6.5571047e-02,
#        -1.1392167e-02,  2.2446120e-01, -1.8778923e-01,  2.9518980e-01,
#         4.5596325e-01, -3.5034940e-01, -2.3182882e-01, -6.9651594e-03,
#         5.0562334e-01,  3.9857793e-01,  8.4961885e-01,  3.7877792e-01,
#         8.0429339e-01, -6.6190902e-03,  3.0028188e-01,  2.2937657e-02,
#        -3.3216801e-02,  5.4149896e-01,  1.0728477e-01,  6.5886366e-01],
#       dtype=float32)

# %%
# 단어의 임베딩 벡터 차원 확인
len(model_sg_n10.wv['이정재'])
# Out:
# 100

# %%
# 두 단어 간 유사도 확인
wv = model_sg_n10.wv
wv.similarity('이정재', '정우성')
# Out:
# np.float32(0.7756181)

# %%
# 특정 단어와 유사한 단어 추출
wv.most_similar('이정재', topn=20)
# Out:
# [('공유', 0.8284235596656799),
#  ('이범수', 0.8228985667228699),
#  ('송강호', 0.820771336555481),
#  ('김범수', 0.7856889963150024),
#  ('정우성', 0.7756180167198181),
#  ('박해일', 0.7670822739601135),
#  ('이성민', 0.7648679614067078),
#  ('김남길', 0.7567336559295654),
#  ('조재현', 0.7450722455978394),
#  ('이진욱', 0.7368229031562805),
#  ('김윤석', 0.7277944684028625),
#  ('김성균', 0.7168622016906738),
#  ('김희원', 0.7161388993263245),
#  ('정재형', 0.715263307094574),
#  ('조정석', 0.7142585515975952),
#  ('주지훈', 0.7121793627738953),
#  ('요한', 0.7115941643714905),
#  ('강원', 0.7113181352615356),
#  ('곽도원', 0.7098833918571472),
#  ('김명민', 0.7053143978118896)]

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '잼남', '재밋음', '재밌네', '재밌었', '재밌어', '재밋구', '재밋었음', '잼슴', '재밌아', '재밋는듯', '쟈밋', '재미있었', '재밋엇음', '재밋엇어용', '재밋엇', '재밋엇어', '재밋어용', '존잼임', '재밋네', '재밋었어', '재밋게봣습니', '재밋습니', '재밋네용', '엇', '꿀잼임', '재밋었습니', '재미있네', '재밌슴', '재밌더', '재밌엇습니', '재밋게봣', '재밋습', '잼난', '잼잇엇음', '존잼', '재미있더', '재밋었', '번보', '재밋게봄', '재밋당', '재밌드', '재밋엇습니', '재밌고', '재밌던', '재밋게봣어', '재밋었네', '강추함', '꿀잼', '안합']

# %% [markdown]
# ### Skipgram, negative=5 인 경우

# %%
# 모델 생성
model_sg_n10 = Word2Vec(token_list, window=3, vector_size=100, min_count=3, sg=1, negative=5)

# %%
# 특어 단어와 유사한 단어 추출 : 이정재
wv = model_sg_n10.wv
print([word for word, _ in wv.most_similar('이정재', topn=50)])
# Out:
# ['이범수', '송강호', '김범수', '공유', '정우성', '이성민', '박해일', '조재현', '이병헌', '주지훈', '곽도원', '김남길', '김명민', '마동석', '요한', '김윤석', '공효진', '송광호', '슨', '이진욱', '리암', '김희원', '조정석', '황정민', '박철민', '공블리', '조진웅', '차승원', '정재형', '정준호', '한지민', '휴그랜트', '수역', '오종혁', '하정우', '오지호', '손혜진', '배성우', '김상호', '김동영', '하디', '윤제문', '유준상', '엄태구', '김남일', '류승범', '김선아', '하시모토', '변', '그랜트']

# %%
# 특어 단어와 유사한 단어 추출 : 재밌
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '재밌네', '잼남', '재밌었', '재밋음', '재밌어', '재밋었음', '재밋엇음', '재밋어용', '재밌아', '재밌슴', '재밋었어', '재미있더', '재미있었', '잼난', '재밋는듯', '재밋습니', '재밋게봣어', '재밋엇어용', '재밋어', '잼슴', '재밋네', '쟈밋', '재미있네', '재밋었습니', '재밋엇', '재밋구', '엇', '재밋엇어', '존잼임', '재밋엇습니', '재미나다', '재밋게봣습니', '재밋습', '재밌더', '재밋게봣음', '재밌엇습니', '존잼', '꾸르잼', '재밋었', '재밌던', '꿀잼임', '더재밋', '재밋당', '번보', '재밋네용', '재밋게봣', '재미있어', '재미있겠', '재밋습니당']

# %% [markdown]
# ### CBOW, negative=10 인 경우

# %%
model_cbow_n10 = Word2Vec(token_list, window=3, vector_size=100, min_count=3, sg=0, negative=10)

# %%
wv = model_cbow_n10.wv
wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.791278600692749),
#  ('공유', 0.7433634996414185),
#  ('조재현', 0.7314646244049072),
#  ('김윤석', 0.7298248410224915),
#  ('이성민', 0.7263027429580688),
#  ('송강호', 0.7189330458641052),
#  ('주지훈', 0.7124564051628113),
#  ('박해일', 0.7089353799819946),
#  ('이진욱', 0.698501706123352),
#  ('김범수', 0.6858900189399719),
#  ('민호', 0.6807251572608948),
#  ('김남길', 0.6689407229423523),
#  ('이병헌', 0.6575188040733337),
#  ('남자배우', 0.6565349698066711),
#  ('곽도원', 0.6555764079093933),
#  ('송광호', 0.6539137363433838),
#  ('엄지원', 0.6504657864570618),
#  ('마동석', 0.6459556818008423),
#  ('조진웅', 0.6455836892127991),
#  ('조정석', 0.6440605521202087)]

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '재밌어', '재밌네', '재밋음', '재밌었', '재밋어', '재미있었', '잼남', '재밌는', '재밋엇어', '재미있네', '재밋네', '재밌더', '재밋', '재밌던', '재미있어', '재밋엇', '재밋었어', '재미있던', '재밌다', '꿀잼', '재밋엇음', '재밌고', '재밋었', '재미있는', '재밋습니', '잼', '재밌게', '재밌구', '재미있다', '재밋었음', '개꿀잼', '웃김', '재밌으', '재미있더', '존잼', '재미있고', '재밌겠', '웃겼', '괜찮', '재미있게', '재미나', '무서웠', '재미없', '재미있겠', '졸잼', '재밋어용', '재밋었습니', '재밋엇습니', '꿀잼임']

# %% [markdown]
# ### CBOW, negative=5 인 경우

# %%
model_cbow_n10 = Word2Vec(token_list, window=3, vector_size=100, min_count=3, sg=0, negative=5)

# %%
wv = model_cbow_n10.wv
wv.most_similar('이정재', topn=20)
# Out:
# [('김윤석', 0.7752479910850525),
#  ('이범수', 0.7516354322433472),
#  ('송강호', 0.7490039467811584),
#  ('공유', 0.7466708421707153),
#  ('조재현', 0.7258554697036743),
#  ('김범수', 0.7247873544692993),
#  ('이성민', 0.7182790040969849),
#  ('김남길', 0.6938290596008301),
#  ('주지훈', 0.684565007686615),
#  ('송광호', 0.6799153089523315),
#  ('이진욱', 0.6781008243560791),
#  ('김성오', 0.6756000518798828),
#  ('하정우', 0.6677901744842529),
#  ('이병헌', 0.6663398742675781),
#  ('박해일', 0.6653525233268738),
#  ('정우성', 0.6593592166900635),
#  ('강예원', 0.6458593010902405),
#  ('조진웅', 0.641791045665741),
#  ('민호', 0.640535295009613),
#  ('요한', 0.6392868757247925)]

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '재밌네', '재밋음', '재밌어', '재밌었', '재밌는', '재미있네', '재밋어', '재미있었', '재밋엇어', '재미있어', '재밌더', '재밌던', '잼남', '재밋', '재밋네', '꿀잼', '재밌다', '재미있는', '재밌고', '재미있던', '재밌구', '재밌게', '재밋었어', '재밋엇', '재밋엇음', '재미있다', '재밋었', '재밋었음', '잼', '웃김', '개꿀잼', '재밌으', '재밋습니', '존잼', '재미있고', '재미있게', '재미있더', '재미나', '재미없', '무서웠', '재밌겠', '웃겼', '재밋었습니', '괜찮', '재미있구', '재밋어용', '무서', '재미있겠', '만족스러웠']

# %% [markdown]
# ### OOV(Out of Vocabulary) 문제

# %%
# corpus에 없는 단어 확인 : 우주평화 
'우주평화' in model_sg_n10.wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
model_sg_n10.wv['우주평화']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 2
#       1 # corpus에 없는 단어의 임베딩 벡터 확인
# ----> 2 model_sg_n10.wv['우주평화']
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key '우주평화' not present"

# %% [markdown]
# ## 2. FastText 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/fasttext.html

# %%
# FastText 모델 생성 및 학습
# window=3, min_count=3, min_n=2, max_n=2
from gensim.models import FastText
model = FastText(token_list, window=3, min_count=3, sg=1, negative=10, vector_size=100, min_n = 2, max_n = 2)
wv = model.wv

# %%
# 특정 단어와 유사한 단어 추출 : 이정재
wv.most_similar('이정재')
# Out:
# [('이범수', 0.8490276336669922),
#  ('정재영', 0.8306418061256409),
#  ('정재', 0.8228834271430969),
#  ('김범수', 0.803955078125),
#  ('정재형', 0.8021482825279236),
#  ('공유', 0.7977772951126099),
#  ('임성민', 0.7975566983222961),
#  ('송강호', 0.7943639755249023),
#  ('박해일', 0.7851677536964417),
#  ('김지민', 0.7654308676719666)]

# %%
# corpus에 없는 단어 확인 : 우주평화 
'우주평화' in wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
wv['우주평화']
# Out:
# array([ 0.29944438,  0.10211988,  0.11245509,  0.20517004,  0.01439658,
#        -0.2340585 , -0.09981678,  0.6836914 ,  0.4607907 ,  0.0662861 ,
#        -0.13002796, -0.03352493,  0.01596562,  0.38126653, -0.15570016,
#        -0.10670888,  0.11131046, -0.19575436,  0.05097123, -0.01182316,
#         0.19543143, -0.08945733,  0.04680297, -0.10861257, -0.09110565,
#        -0.17837285, -0.53734577, -0.22740825, -0.22581477, -0.2745905 ,
#         0.10999994, -0.41968173,  0.3312001 , -0.3333724 , -0.01522877,
#         0.21800609,  0.021394  ,  0.28397852, -0.44447803, -0.02694625,
#        -0.07837706,  0.05109895, -0.02012579,  0.03657988, -0.13307428,
#         0.1258792 , -0.26446337,  0.10918796, -0.02650501,  0.03953478,
#         0.5412389 ,  0.19158861, -0.1984783 , -0.08819991, -0.09384322,
#        -0.11210287,  0.41666046,  0.30603725,  0.2158771 ,  0.13991472,
#         0.0627256 ,  0.3344077 , -0.6267226 ,  0.01454694, -0.22027841,
#        -0.38652426, -0.12105286, -0.22153887, -0.16127567,  0.0444328 ,
#        -0.09032539, -0.02605417,  0.21538165,  0.07057641, -0.05859863,
#        -0.04737747, -0.01790497, -0.26043552, -0.00230632, -0.16477284,
#        -0.42658573, -0.44091186,  0.04469637,  0.1871867 ,  0.32231596,
#        -0.12938908, -0.16502619,  0.20516248, -0.14958112,  0.01767925,
#         0.16195694,  0.43445134, -0.4820455 , -0.02934798,  0.13263507,
#         0.571276  , -0.16151972, -0.22028108, -0.23641114,  0.24798974],
#       dtype=float32)

# %%
# corpus에 없는 단어와 유사한 단어추출 
wv.most_similar('우주평화', topn=20)
# Out:
# [('우주', 0.8291060328483582),
#  ('우주비행사', 0.8164864182472229),
#  ('평화', 0.799358606338501),
#  ('회색곰', 0.7966422438621521),
#  ('우방', 0.7913792729377747),
#  ('우주선', 0.7895830273628235),
#  ('우주인', 0.7870504260063171),
#  ('우장', 0.7859303951263428),
#  ('켤', 0.7784541845321655),
#  ('우주여행', 0.7747458219528198),
#  ('산화', 0.7685962319374084),
#  ('투명인간', 0.7652707695960999),
#  ('전투복', 0.7650793790817261),
#  ('경복궁', 0.764390230178833),
#  ('우화', 0.7627337574958801),
#  ('우주전쟁', 0.7626222968101501),
#  ('볐', 0.7623069882392883),
#  ('산전수전', 0.7614326477050781),
#  ('쉘', 0.7600038647651672),
#  ('아우슈비츠', 0.7595550417900085)]
